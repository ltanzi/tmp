# %%
import nest_asyncio
nest_asyncio.apply()

import pandas as pd
from datetime import datetime, timedelta
from pathlib import Path
import os
import time
import SimpleITK as sitk
import datetime
import sys
import random
import pydicom

from addict import Dict
import numpy as np
from django.db import close_old_connections
from mtk_lib.sitk import transform_image2image

######### SETUP
from django import setup
sys.path.insert(0, '/usr/local/share/methinks/stroke_web')
os.environ['DJANGO_SETTINGS_MODULE'] = 'stroke_web.settings'
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
setup()
####################
from stroke.models import Diagnostic, Image, Case, Patient, Configuration, Institution, NeuralModel, User
import az_stge_client

# %%
stroke_db_path = '/data/stroke/database/'
disk_mask_path = '/export/JEREMYDISK/NCCT/data/atlas_int16/distmask_int16.nii.gz'
atlas_distmask= sitk.ReadImage(disk_mask_path)

# %%
overlays_path = '/export/NASDISK/cgranes/tmp/ad_tici3/ctrl'
images_path = '/export/NASDISK/cgranes/tmp/ad_tici3/images'

# %%
def create_empty_diagnostic_overlay(img):
    diagnostic = Diagnostic()
    diagnostic.image = img
    diagnostic.type = Diagnostic.OVERLAY
    diagnostic.data = {"aspects": {}, "version": "1.0", 
                       "segmentation": {'lesions': {"Chronic": {"ml": "0.00","code": 3,"color": "#06337a"},
                                                    "Subacute": {"ml": "0.00","code": 1,"color": "#295e6e"},
                                                    "Hemorrhage": {"ml": "0.00","code": 2,"color": "#dd3e1f"}
                                                   }
                                       }}

    diagnostic.date = datetime.datetime.now()
    if 'DL' in img.patient.uid:
        diagnostic.notes = 'DWI'
    else:
        diagnostic.notes = 'Control'
    diagnostic.save()
    return diagnostic

def hex2rgb(value):
    value = value.lstrip('#')
    return list(int(value[i:i+2], 16) for i in (0, 2 ,4))

def format_ml(ml):
    return '%.2f'%ml if ml<10 else '%.1f'%ml if ml<100 else '%.0f'%ml

def calculate_segmentation_data_for_ncct(diagnostic_data, diagnostic_model, brain_mask):
    max_lesion_code = max([details['code'] for _, details in diagnostic_model.data['segmentation']['lesions'].items()])
#     we need to add one as count start at 0 (background class)
    label_counts = np.bincount(diagnostic_data.flatten(), minlength= max_lesion_code + 1)
    voxel_ml = diagnostic_model.ml_per_voxel()
    seg_ml = list([c*diagnostic_model.ml_per_voxel() for c in label_counts])
    lesions = {}
    data = {}
    if brain_mask is not None:
        total_brain_volume = np.sum((brain_mask != 0).astype(np.int32)) * voxel_ml
        data['Brain'] = {'ml': np.around(total_brain_volume, decimals=4), 'code': -1}
        
    for lesion, details in diagnostic_model.data['segmentation']['lesions'].items():
        lesions[lesion] = {}
        for detail_key, detail_content in details.items():
            lesions[lesion][detail_key] = detail_content
        lesions[lesion]['ml'] = format_ml(seg_ml[details['code']])
        data[lesion] = {'ml': np.around(seg_ml[details['code']], decimals=4), 'code': details['code']}
    json_data = {'lesions': lesions, 'data': data}
    return json_data


def update_diagnostic_model(ncct, diagnostic, file_path, img, seg_data, registration):
    diagnostic.nii_path = file_path
    ## compute metrics:
    if registration is not None:
        dist_mask = sitk.GetArrayFromImage(transform_image2image(ncct, atlas_distmask,
                                                                 registration, direction='backward', order=0))
        relevant_volume_mask = (dist_mask > 0).astype(np.int16)
    else:
        relevant_volume_mask = None
    
    segmentation_data = calculate_segmentation_data_for_ncct(seg_data, diagnostic, relevant_volume_mask)
    diagnostic.data['segmentation'] = segmentation_data
    diagnostic.save()

# %%
def update_diag(diag, ncct, img, seg_img, orig_seg_path, registration):
    inference_folder = img.get_nii_path().replace('.nii.gz','')
    seg_path = os.path.join(inference_folder, '%d_O.nii.gz' % (diag.id) )
    
    
    print(seg_path)
    #### copy nifti to path in stroke (provisional)
    os.system(f"mkdir -p {os.path.dirname(seg_path)}")
    os.system(f"cp {orig_seg_path} {seg_path}")
    ## upload to azure
    az_stge_client.upload(seg_path)
    
    #'''
    seg_data = sitk.GetArrayFromImage(seg_img)
    update_diagnostic_model(ncct, diag, seg_path.replace(stroke_db_path,''), 
                            img, seg_data, registration)
    diag.save()#'''
    return diag

def create_diag(ncct, img, seg_img, orig_seg_path, registration):
    diag = create_empty_diagnostic_overlay(img)
    print('empty',diag.id)
    d = update_diag(diag, ncct, img, seg_img, orig_seg_path, registration)
    return d

# %%
for f in os.listdir(overlays_path):
    image_id = int(f.split('_')[1].replace('.nii.gz',''))
    print(f, image_id)
    image = Image.objects.get(id=image_id)
    #'''
    ncct = sitk.ReadImage(os.path.join(images_path, f))
    orig_seg_path = os.path.join(overlays_path, f)
    seg_img = sitk.ReadImage(orig_seg_path)
    
    d=create_diag(ncct, image, seg_img, orig_seg_path, registration=image.registration)
    print('created ',d.id)#'''
# Out:
# VH09372_51207.nii.gz 51207
# empty 190977
# /data/stroke/database/vh_treated/images/VH09372/51207_NCCT/190977_O.nii.gz
# created  190977
# VH11297_51215.nii.gz 51215
# empty 190978
# /data/stroke/database/vh_treated/images/VH11297/51215_NCCT/190978_O.nii.gz
# created  190978
# VH03870_51245.nii.gz 51245
# empty 190979
# /data/stroke/database/vh_treated/images/VH03870/51245_NCCT/190979_O.nii.gz
# created  190979
# VH39312_51249.nii.gz 51249
# empty 190980
# /data/stroke/database/vh_treated/images/VH39312/51249_NCCT/190980_O.nii.gz
# created  190980
# VH14780_51257.nii.gz 51257
# empty 190981
# /data/stroke/database/vh_treated/images/VH14780/51257_NCCT/190981_O.nii.gz
# created  190981
# VH57033_51283.nii.gz 51283
# empty 190982
# /data/stroke/database/vh_treated/images/VH57033/51283_NCCT/190982_O.nii.gz
# created  190982
# VH52974_51291.nii.gz 51291
# empty 190983
# /data/stroke/database/vh_treated/images/VH52974/51291_NCCT/190983_O.nii.gz
# created  190983
# VH30427_51337.nii.gz 51337
# empty 190984
# /data/stroke/database/vh_treated/images/VH30427/51337_NCCT/190984_O.nii.gz
# created  190984
# VH55974_51370.nii.gz 51370
# empty 190985
# /data/stroke/database/vh_treated/images/VH55974/51370_NCCT/190985_O.nii.gz
# created  190985
# VH77250_51382.nii.gz 51382
# empty 190986
# /data/stroke/database/vh_treated/images/VH77250/51382_NCCT/190986_O.nii.gz
# created  190986
# VH62654_51394.nii.gz 51394
# empty 190987
# /data/stroke/database/vh_treated/images/VH62654/51394_NCCT/190987_O.nii.gz
# created  190987
# VH58848_51409.nii.gz 51409
# empty 190988
# /data/stroke/database/vh_treated/images/VH58848/51409_NCCT/190988_O.nii.gz
# created  190988
# VH08904_51415.nii.gz 51415
# empty 190989
# /data/stroke/database/vh_treated/images/VH08904/51415_NCCT/190989_O.nii.gz
# created  190989
# VH67614_51446.nii.gz 51446
# empty 190990
# /data/stroke/database/vh_treated/images/VH67614/51446_NCCT/190990_O.nii.gz
# created  190990
# VH02248_51476.nii.gz 51476
# empty 190991
# /data/stroke/database/vh_treated/images/VH02248/51476_NCCT/190991_O.nii.gz
# created  190991
# VH17705_51641.nii.gz 51641
# empty 190992
# /data/stroke/database/vh_treated/images/VH17705/51641_NCCT/190992_O.nii.gz
# created  190992
# VH64457_51677.nii.gz 51677
# empty 190993
# /data/stroke/database/vh_treated/images/VH64457/51677_NCCT/190993_O.nii.gz
# created  190993
# VH32083_51680.nii.gz 51680
# empty 190994
# /data/stroke/database/vh_treated/images/VH32083/51680_NCCT/190994_O.nii.gz
# created  190994
# VH82893_51717.nii.gz 51717
# empty 190995
# /data/stroke/database/vh_treated/images/VH82893/51717_NCCT/190995_O.nii.gz
# created  190995
# VH14590_51806.nii.gz 51806
# empty 190996
# /data/stroke/database/vh_treated/images/VH14590/51806_NCCT/190996_O.nii.gz
# created  190996
# VH45801_51815.nii.gz 51815
# empty 190997
# /data/stroke/database/vh_treated/images/VH45801/51815_NCCT/190997_O.nii.gz
# created  190997
# VH46600_51832.nii.gz 51832
# empty 190998
# /data/stroke/database/vh_treated/images/VH46600/51832_NCCT/190998_O.nii.gz
# created  190998
# VH08585_51861.nii.gz 51861
# empty 190999
# /data/stroke/database/vh_treated/images/VH08585/51861_NCCT/190999_O.nii.gz
# created  190999
# VH17699_51881.nii.gz 51881
# empty 191000
# /data/stroke/database/vh_treated/images/VH17699/51881_NCCT/191000_O.nii.gz
# created  191000
# VH83696_51893.nii.gz 51893
# empty 191001
# /data/stroke/database/vh_treated/images/VH83696/51893_NCCT/191001_O.nii.gz
# created  191001
# VH31670_51941.nii.gz 51941
# empty 191002
# /data/stroke/database/vh_treated/images/VH31670/51941_NCCT/191002_O.nii.gz
# created  191002
# VH66232_51952.nii.gz 51952
# empty 191003
# /data/stroke/database/vh_treated/images/VH66232/51952_NCCT/191003_O.nii.gz
# created  191003
# VH09822_52099.nii.gz 52099
# empty 191004
# /data/stroke/database/vh_treated/images/VH09822/52099_NCCT/191004_O.nii.gz
# created  191004
# VH98990_52111.nii.gz 52111
# empty 191005
# /data/stroke/database/vh_treated/images/VH98990/52111_NCCT/191005_O.nii.gz
# created  191005
# VH10507_52125.nii.gz 52125
# empty 191006
# /data/stroke/database/vh_treated/images/VH10507/52125_NCCT/191006_O.nii.gz
# created  191006
# VH80814_52179.nii.gz 52179
# empty 191007
# /data/stroke/database/vh_treated/images/VH80814/52179_NCCT/191007_O.nii.gz
# created  191007
# VH96033_52224.nii.gz 52224
# empty 191008
# /data/stroke/database/vh_treated/images/VH96033/52224_NCCT/191008_O.nii.gz
# created  191008
# VH99867_52258.nii.gz 52258
# empty 191009
# /data/stroke/database/vh_treated/images/VH99867/52258_NCCT/191009_O.nii.gz
# created  191009
# VH48526_52357.nii.gz 52357
# empty 191010
# /data/stroke/database/vh_treated/images/VH48526/52357_NCCT/191010_O.nii.gz
# created  191010
# VH47403_54275.nii.gz 54275
# empty 191011
# /data/stroke/database/vh_treated/images/VH47403/54275_NCCT/191011_O.nii.gz
# created  191011
# VH37354_52390.nii.gz 52390
# empty 191012
# /data/stroke/database/vh_treated/images/VH37354/52390_NCCT/191012_O.nii.gz
# created  191012
# VH22166_52446.nii.gz 52446
# empty 191013
# /data/stroke/database/vh_treated/images/VH22166/52446_NCCT/191013_O.nii.gz
# created  191013
# VH58752_52452.nii.gz 52452
# empty 191014
# /data/stroke/database/vh_treated/images/VH58752/52452_NCCT/191014_O.nii.gz
# created  191014
# VH02110_52520.nii.gz 52520
# empty 191015
# /data/stroke/database/vh_treated/images/VH02110/52520_NCCT/191015_O.nii.gz
# created  191015
# VH16170_52535.nii.gz 52535
# empty 191016
# /data/stroke/database/vh_treated/images/VH16170/52535_NCCT/191016_O.nii.gz
# created  191016
# VH38576_52541.nii.gz 52541
# empty 191017
# /data/stroke/database/vh_treated/images/VH38576/52541_NCCT/191017_O.nii.gz
# created  191017
# VH92350_52556.nii.gz 52556
# empty 191018
# /data/stroke/database/vh_treated/images/VH92350/52556_NCCT/191018_O.nii.gz
# created  191018
# VH32727_52566.nii.gz 52566
# empty 191019
# /data/stroke/database/vh_treated/images/VH32727/52566_NCCT/191019_O.nii.gz
# created  191019
# VH98774_52582.nii.gz 52582
# empty 191020
# /data/stroke/database/vh_treated/images/VH98774/52582_NCCT/191020_O.nii.gz
# created  191020
# VH75351_52618.nii.gz 52618
# empty 191021
# /data/stroke/database/vh_treated/images/VH75351/52618_NCCT/191021_O.nii.gz
# created  191021
# VH10234_52621.nii.gz 52621
# empty 191022
# /data/stroke/database/vh_treated/images/VH10234/52621_NCCT/191022_O.nii.gz
# created  191022
# VH10173_52656.nii.gz 52656
# empty 191023
# /data/stroke/database/vh_treated/images/VH10173/52656_NCCT/191023_O.nii.gz
# created  191023
# VH86628_52671.nii.gz 52671
# empty 191024
# /data/stroke/database/vh_treated/images/VH86628/52671_NCCT/191024_O.nii.gz
# created  191024
# VH15959_52690.nii.gz 52690
# empty 191025
# /data/stroke/database/vh_treated/images/VH15959/52690_NCCT/191025_O.nii.gz
# created  191025
# VH36009_52714.nii.gz 52714
# empty 191026
# /data/stroke/database/vh_treated/images/VH36009/52714_NCCT/191026_O.nii.gz
# created  191026
# VH12558_52740.nii.gz 52740
# empty 191027
# /data/stroke/database/vh_treated/images/VH12558/52740_NCCT/191027_O.nii.gz
# created  191027
# VH67230_52820.nii.gz 52820
# empty 191028
# /data/stroke/database/vh_treated/images/VH67230/52820_NCCT/191028_O.nii.gz
# created  191028
# VH12120_52826.nii.gz 52826
# empty 191029
# /data/stroke/database/vh_treated/images/VH12120/52826_NCCT/191029_O.nii.gz
# created  191029
# VH59686_52833.nii.gz 52833
# empty 191030
# /data/stroke/database/vh_treated/images/VH59686/52833_NCCT/191030_O.nii.gz
# created  191030
# VH64398_52851.nii.gz 52851
# empty 191031
# /data/stroke/database/vh_treated/images/VH64398/52851_NCCT/191031_O.nii.gz
# created  191031
# VH91619_52866.nii.gz 52866
# empty 191032
# /data/stroke/database/vh_treated/images/VH91619/52866_NCCT/191032_O.nii.gz
# created  191032
# VH25309_52872.nii.gz 52872
# empty 191033
# /data/stroke/database/vh_treated/images/VH25309/52872_NCCT/191033_O.nii.gz
# created  191033
# VH39177_52896.nii.gz 52896
# empty 191034
# /data/stroke/database/vh_treated/images/VH39177/52896_NCCT/191034_O.nii.gz
# created  191034
# VH96517_52909.nii.gz 52909
# empty 191035
# /data/stroke/database/vh_treated/images/VH96517/52909_NCCT/191035_O.nii.gz
# created  191035
# VH98926_52922.nii.gz 52922
# empty 191036
# /data/stroke/database/vh_treated/images/VH98926/52922_NCCT/191036_O.nii.gz
# created  191036
# VH06981_52958.nii.gz 52958
# empty 191037
# /data/stroke/database/vh_treated/images/VH06981/52958_NCCT/191037_O.nii.gz
# created  191037
# VH59260_52978.nii.gz 52978
# empty 191038
# /data/stroke/database/vh_treated/images/VH59260/52978_NCCT/191038_O.nii.gz
# created  191038
# VH42482_52988.nii.gz 52988
# empty 191039
# /data/stroke/database/vh_treated/images/VH42482/52988_NCCT/191039_O.nii.gz
# created  191039
# VH33188_53012.nii.gz 53012
# empty 191040
# /data/stroke/database/vh_treated/images/VH33188/53012_NCCT/191040_O.nii.gz
# created  191040
# VH48302_52352.nii.gz 52352
# empty 191041
# /data/stroke/database/vh_treated/images/VH48302/52352_NCCT/191041_O.nii.gz
# created  191041
# VH56568_53069.nii.gz 53069
# empty 191042
# /data/stroke/database/vh_treated/images/VH56568/53069_NCCT/191042_O.nii.gz
# created  191042
# VH96633_53100.nii.gz 53100
# empty 191043
# /data/stroke/database/vh_treated/images/VH96633/53100_NCCT/191043_O.nii.gz
# created  191043
# VH68526_53156.nii.gz 53156
# empty 191044
# /data/stroke/database/vh_treated/images/VH68526/53156_NCCT/191044_O.nii.gz
# created  191044
# VH41628_53171.nii.gz 53171
# empty 191045
# /data/stroke/database/vh_treated/images/VH41628/53171_NCCT/191045_O.nii.gz
# created  191045
# VH00921_53182.nii.gz 53182
# empty 191046
# /data/stroke/database/vh_treated/images/VH00921/53182_NCCT/191046_O.nii.gz
# created  191046
# VH76451_53185.nii.gz 53185
# empty 191047
# /data/stroke/database/vh_treated/images/VH76451/53185_NCCT/191047_O.nii.gz
# created  191047
# VH56456_53215.nii.gz 53215
# empty 191048
# /data/stroke/database/vh_treated/images/VH56456/53215_NCCT/191048_O.nii.gz
# created  191048
# VH10163_53260.nii.gz 53260
# empty 191049
# /data/stroke/database/vh_treated/images/VH10163/53260_NCCT/191049_O.nii.gz
# created  191049
# VH38434_53270.nii.gz 53270
# empty 191050
# /data/stroke/database/vh_treated/images/VH38434/53270_NCCT/191050_O.nii.gz
# created  191050
# VH29910_53298.nii.gz 53298
# empty 191051
# /data/stroke/database/vh_treated/images/VH29910/53298_NCCT/191051_O.nii.gz
# created  191051
# VH52359_53311.nii.gz 53311
# empty 191052
# /data/stroke/database/vh_treated/images/VH52359/53311_NCCT/191052_O.nii.gz
# created  191052
# VH26335_53323.nii.gz 53323
# empty 191053
# /data/stroke/database/vh_treated/images/VH26335/53323_NCCT/191053_O.nii.gz
# created  191053
# VH20736_53382.nii.gz 53382
# empty 191054
# /data/stroke/database/vh_treated/images/VH20736/53382_NCCT/191054_O.nii.gz
# created  191054
# VH00071_53393.nii.gz 53393
# empty 191055
# /data/stroke/database/vh_treated/images/VH00071/53393_NCCT/191055_O.nii.gz
# created  191055
# VH89722_53411.nii.gz 53411
# empty 191056
# /data/stroke/database/vh_treated/images/VH89722/53411_NCCT/191056_O.nii.gz
# created  191056
# VH76345_53441.nii.gz 53441
# empty 191057
# /data/stroke/database/vh_treated/images/VH76345/53441_NCCT/191057_O.nii.gz
# created  191057
# VH75661_53540.nii.gz 53540
# empty 191058
# /data/stroke/database/vh_treated/images/VH75661/53540_NCCT/191058_O.nii.gz
# created  191058
# VH55648_53549.nii.gz 53549
# empty 191059
# /data/stroke/database/vh_treated/images/VH55648/53549_NCCT/191059_O.nii.gz
# created  191059
# VH53028_53582.nii.gz 53582
# empty 191060
# /data/stroke/database/vh_treated/images/VH53028/53582_NCCT/191060_O.nii.gz
# created  191060
# VH87385_53608.nii.gz 53608
# empty 191061
# /data/stroke/database/vh_treated/images/VH87385/53608_NCCT/191061_O.nii.gz
# created  191061
# VH22404_53612.nii.gz 53612
# empty 191062
# /data/stroke/database/vh_treated/images/VH22404/53612_NCCT/191062_O.nii.gz
# created  191062
# VH80908_53657.nii.gz 53657
# empty 191063
# /data/stroke/database/vh_treated/images/VH80908/53657_NCCT/191063_O.nii.gz
# created  191063
# VH66856_53719.nii.gz 53719
# empty 191064
# /data/stroke/database/vh_treated/images/VH66856/53719_NCCT/191064_O.nii.gz
# created  191064
# VH99489_53746.nii.gz 53746
# empty 191065
# /data/stroke/database/vh_treated/images/VH99489/53746_NCCT/191065_O.nii.gz
# created  191065
# VH15320_53770.nii.gz 53770
# empty 191066
# /data/stroke/database/vh_treated/images/VH15320/53770_NCCT/191066_O.nii.gz
# created  191066
# VH38750_53866.nii.gz 53866
# empty 191067
# /data/stroke/database/vh_treated/images/VH38750/53866_NCCT/191067_O.nii.gz
# created  191067
# VH82321_53880.nii.gz 53880
# empty 191068
# /data/stroke/database/vh_treated/images/VH82321/53880_NCCT/191068_O.nii.gz
# created  191068
# VH11804_53922.nii.gz 53922
# empty 191069
# /data/stroke/database/vh_treated/images/VH11804/53922_NCCT/191069_O.nii.gz
# created  191069
# VH75559_53940.nii.gz 53940
# empty 191070
# /data/stroke/database/vh_treated/images/VH75559/53940_NCCT/191070_O.nii.gz
# created  191070
# VH53369_53986.nii.gz 53986
# empty 191071
# /data/stroke/database/vh_treated/images/VH53369/53986_NCCT/191071_O.nii.gz
# created  191071
# VH98776_53991.nii.gz 53991
# empty 191072
# /data/stroke/database/vh_treated/images/VH98776/53991_NCCT/191072_O.nii.gz
# created  191072
# VH62290_54017.nii.gz 54017
# empty 191073
# /data/stroke/database/vh_treated/images/VH62290/54017_NCCT/191073_O.nii.gz
# created  191073
# VH72677_54039.nii.gz 54039
# empty 191074
# /data/stroke/database/vh_treated/images/VH72677/54039_NCCT/191074_O.nii.gz
# created  191074
# VH01568_54058.nii.gz 54058
# empty 191075
# /data/stroke/database/vh_treated/images/VH01568/54058_NCCT/191075_O.nii.gz
# created  191075
# VH23856_54309.nii.gz 54309
# empty 191076
# /data/stroke/database/vh_treated/images/VH23856/54309_NCCT/191076_O.nii.gz
# created  191076
# VH78908_54495.nii.gz 54495
# empty 191077
# /data/stroke/database/vh_treated/images/VH78908/54495_NCCT/191077_O.nii.gz
# created  191077
# VH29347_54579.nii.gz 54579
# empty 191078
# /data/stroke/database/vh_treated/images/VH29347/54579_NCCT/191078_O.nii.gz
# created  191078
# VH19012_54658.nii.gz 54658
# empty 191079
# /data/stroke/database/vh_treated/images/VH19012/54658_NCCT/191079_O.nii.gz
# created  191079
# VH99026_54669.nii.gz 54669
# empty 191080
# /data/stroke/database/vh_treated/images/VH99026/54669_NCCT/191080_O.nii.gz
# created  191080
# VH08708_54694.nii.gz 54694
# empty 191081
# /data/stroke/database/vh_treated/images/VH08708/54694_NCCT/191081_O.nii.gz
# created  191081
# VH49751_54738.nii.gz 54738
# empty 191082
# /data/stroke/database/vh_treated/images/VH49751/54738_NCCT/191082_O.nii.gz
# created  191082
# VH92128_54782.nii.gz 54782
# empty 191083
# /data/stroke/database/vh_treated/images/VH92128/54782_NCCT/191083_O.nii.gz
# created  191083
# VH69436_54790.nii.gz 54790
# empty 191084
# /data/stroke/database/vh_treated/images/VH69436/54790_NCCT/191084_O.nii.gz
# created  191084
# VH06021_54852.nii.gz 54852
# empty 191085
# /data/stroke/database/vh_treated/images/VH06021/54852_NCCT/191085_O.nii.gz
# created  191085
# VH37456_54937.nii.gz 54937
# empty 191086
# /data/stroke/database/vh_treated/images/VH37456/54937_NCCT/191086_O.nii.gz
# created  191086
# VH42791_55008.nii.gz 55008
# empty 191087
# /data/stroke/database/vh_treated/images/VH42791/55008_NCCT/191087_O.nii.gz
# created  191087
# VH13114_55080.nii.gz 55080
# empty 191088
# /data/stroke/database/vh_treated/images/VH13114/55080_NCCT/191088_O.nii.gz
# created  191088
# VH07652_55177.nii.gz 55177
# empty 191089
# /data/stroke/database/vh_treated/images/VH07652/55177_NCCT/191089_O.nii.gz
# created  191089
# VH90033_55185.nii.gz 55185
# empty 191090
# /data/stroke/database/vh_treated/images/VH90033/55185_NCCT/191090_O.nii.gz
# created  191090
# VH71417_55198.nii.gz 55198
# empty 191091
# /data/stroke/database/vh_treated/images/VH71417/55198_NCCT/191091_O.nii.gz
# created  191091
# VH91722_55211.nii.gz 55211
# empty 191092
# /data/stroke/database/vh_treated/images/VH91722/55211_NCCT/191092_O.nii.gz
# created  191092
# VH22428_55231.nii.gz 55231
# empty 191093
# /data/stroke/database/vh_treated/images/VH22428/55231_NCCT/191093_O.nii.gz
# created  191093
# VH80868_55322.nii.gz 55322
# empty 191094
# /data/stroke/database/vh_treated/images/VH80868/55322_NCCT/191094_O.nii.gz
# created  191094
# VH11597_55363.nii.gz 55363
# empty 191095
# /data/stroke/database/vh_treated/images/VH11597/55363_NCCT/191095_O.nii.gz
# created  191095
# VH76672_55367.nii.gz 55367
# empty 191096
# /data/stroke/database/vh_treated/images/VH76672/55367_NCCT/191096_O.nii.gz
# created  191096
# VH98517_55409.nii.gz 55409
# empty 191097
# /data/stroke/database/vh_treated/images/VH98517/55409_NCCT/191097_O.nii.gz
# created  191097
# VH12255_55420.nii.gz 55420
# empty 191098
# /data/stroke/database/vh_treated/images/VH12255/55420_NCCT/191098_O.nii.gz
# created  191098
# VH32372_55446.nii.gz 55446
# empty 191099
# /data/stroke/database/vh_treated/images/VH32372/55446_NCCT/191099_O.nii.gz
# created  191099
# VH10349_55519.nii.gz 55519
# empty 191100
# /data/stroke/database/vh_treated/images/VH10349/55519_NCCT/191100_O.nii.gz
# created  191100
# VH61670_55546.nii.gz 55546
# empty 191101
# /data/stroke/database/vh_treated/images/VH61670/55546_NCCT/191101_O.nii.gz
# created  191101
# VH25885_55556.nii.gz 55556
# empty 191102
# /data/stroke/database/vh_treated/images/VH25885/55556_NCCT/191102_O.nii.gz
# created  191102
# VH89984_55594.nii.gz 55594
# empty 191103
# /data/stroke/database/vh_treated/images/VH89984/55594_NCCT/191103_O.nii.gz
# created  191103
# VH33746_55606.nii.gz 55606
# empty 191104
# /data/stroke/database/vh_treated/images/VH33746/55606_NCCT/191104_O.nii.gz
# created  191104
# VH68541_55624.nii.gz 55624
# empty 191105
# /data/stroke/database/vh_treated/images/VH68541/55624_NCCT/191105_O.nii.gz
# created  191105
# VH26047_55658.nii.gz 55658
# empty 191106
# /data/stroke/database/vh_treated/images/VH26047/55658_NCCT/191106_O.nii.gz
# created  191106
# VH99490_55666.nii.gz 55666
# empty 191107
# /data/stroke/database/vh_treated/images/VH99490/55666_NCCT/191107_O.nii.gz
# created  191107
# VH39050_55789.nii.gz 55789
# empty 191108
# /data/stroke/database/vh_treated/images/VH39050/55789_NCCT/191108_O.nii.gz
# created  191108
# VH37404_55801.nii.gz 55801
# empty 191109
# /data/stroke/database/vh_treated/images/VH37404/55801_NCCT/191109_O.nii.gz
# created  191109
# VH34901_55827.nii.gz 55827
# empty 191110
# /data/stroke/database/vh_treated/images/VH34901/55827_NCCT/191110_O.nii.gz
# created  191110
# VH85814_55948.nii.gz 55948
# empty 191111
# /data/stroke/database/vh_treated/images/VH85814/55948_NCCT/191111_O.nii.gz
# created  191111
# DL0008_4842.nii.gz 4842
# empty 191112
# /data/stroke/database/clinic/images/DL0008/4842_NCCT/191112_O.nii.gz
# created  191112
# DL0017_4851.nii.gz 4851
# empty 191113
# /data/stroke/database/clinic/images/DL0017/4851_NCCT/191113_O.nii.gz
# created  191113
# DL0018_4852.nii.gz 4852
# empty 191114
# /data/stroke/database/clinic/images/DL0018/4852_NCCT/191114_O.nii.gz
# created  191114
# DL0059_4889.nii.gz 4889
# empty 191115
# /data/stroke/database/clinic/images/DL0059/4889_NCCT/191115_O.nii.gz
# created  191115
# DL0060_4890.nii.gz 4890
# empty 191116
# /data/stroke/database/clinic/images/DL0060/4890_NCCT/191116_O.nii.gz
# created  191116
# DL0108_4932.nii.gz 4932
# empty 191117
# /data/stroke/database/clinic/images/DL0108/4932_NCCT/191117_O.nii.gz
# created  191117
# DL0113_4936.nii.gz 4936
# empty 191118
# /data/stroke/database/clinic/images/DL0113/4936_NCCT/191118_O.nii.gz
# created  191118
# DL0116_4939.nii.gz 4939
# empty 191119
# /data/stroke/database/clinic/images/DL0116/4939_NCCT/191119_O.nii.gz
# created  191119
# DL0121_4943.nii.gz 4943
# empty 191120
# /data/stroke/database/clinic/images/DL0121/4943_NCCT/191120_O.nii.gz
# created  191120
# DL0130_4952.nii.gz 4952
# empty 191121
# /data/stroke/database/clinic/images/DL0130/4952_NCCT/191121_O.nii.gz
# created  191121
# DL0153_4968.nii.gz 4968
# empty 191122
# /data/stroke/database/clinic/images/DL0153/4968_NCCT/191122_O.nii.gz
# created  191122
# DL0170_4980.nii.gz 4980
# empty 191123
# /data/stroke/database/clinic/images/DL0170/4980_NCCT/191123_O.nii.gz
# created  191123
# DL0172_4982.nii.gz 4982
# empty 191124
# /data/stroke/database/clinic/images/DL0172/4982_NCCT/191124_O.nii.gz
# created  191124
# DL0175_4985.nii.gz 4985
# empty 191125
# /data/stroke/database/clinic/images/DL0175/4985_NCCT/191125_O.nii.gz
# created  191125
# DL0180_4989.nii.gz 4989
# empty 191126
# /data/stroke/database/clinic/images/DL0180/4989_NCCT/191126_O.nii.gz
# created  191126
# DL0207_5013.nii.gz 5013
# empty 191127
# /data/stroke/database/clinic/images/DL0207/5013_NCCT/191127_O.nii.gz
# created  191127
# DL0219_5025.nii.gz 5025
# empty 191128
# /data/stroke/database/clinic/images/DL0219/5025_NCCT/191128_O.nii.gz
# created  191128
# DL0236_5040.nii.gz 5040
# empty 191129
# /data/stroke/database/clinic/images/DL0236/5040_NCCT/191129_O.nii.gz
# created  191129
# DL0241_5044.nii.gz 5044
# empty 191130
# /data/stroke/database/clinic/images/DL0241/5044_NCCT/191130_O.nii.gz
# created  191130
# DL0244_5047.nii.gz 5047
# empty 191131
# /data/stroke/database/clinic/images/DL0244/5047_NCCT/191131_O.nii.gz
# created  191131
# DL0249_5052.nii.gz 5052
# empty 191132
# /data/stroke/database/clinic/images/DL0249/5052_NCCT/191132_O.nii.gz
# created  191132
# DL0277_5078.nii.gz 5078
# empty 191133
# /data/stroke/database/clinic/images/DL0277/5078_NCCT/191133_O.nii.gz
# created  191133
# DL0278_5079.nii.gz 5079
# empty 191134
# /data/stroke/database/clinic/images/DL0278/5079_NCCT/191134_O.nii.gz
# created  191134
# DL0290_5091.nii.gz 5091
# empty 191135
# /data/stroke/database/clinic/images/DL0290/5091_NCCT/191135_O.nii.gz
# created  191135
# DL0323_5121.nii.gz 5121
# empty 191136
# /data/stroke/database/clinic/images/DL0323/5121_NCCT/191136_O.nii.gz
# created  191136
# DL0325_5123.nii.gz 5123
# empty 191137
# /data/stroke/database/clinic/images/DL0325/5123_NCCT/191137_O.nii.gz
# created  191137
# DL0326_5124.nii.gz 5124
# empty 191138
# /data/stroke/database/clinic/images/DL0326/5124_NCCT/191138_O.nii.gz
# created  191138
# DL0341_5139.nii.gz 5139
# empty 191139
# /data/stroke/database/clinic/images/DL0341/5139_NCCT/191139_O.nii.gz
# created  191139
# DL0364_5162.nii.gz 5162
# empty 191140
# /data/stroke/database/clinic/images/DL0364/5162_NCCT/191140_O.nii.gz
# created  191140
# DL0448_5240.nii.gz 5240
# empty 191141
# /data/stroke/database/clinic/images/DL0448/5240_NCCT/191141_O.nii.gz
# created  191141
# DL0457_5247.nii.gz 5247
# empty 191142
# /data/stroke/database/clinic/images/DL0457/5247_NCCT/191142_O.nii.gz
# created  191142
# DL0464_5253.nii.gz 5253
# empty 191143
# /data/stroke/database/clinic/images/DL0464/5253_NCCT/191143_O.nii.gz
# created  191143
# DL0471_5259.nii.gz 5259
# empty 191144
# /data/stroke/database/clinic/images/DL0471/5259_NCCT/191144_O.nii.gz
# created  191144
# DL0476_5264.nii.gz 5264
# empty 191145
# /data/stroke/database/clinic/images/DL0476/5264_NCCT/191145_O.nii.gz
# created  191145
# DL0480_5268.nii.gz 5268
# empty 191146
# /data/stroke/database/clinic/images/DL0480/5268_NCCT/191146_O.nii.gz
# created  191146
# DL0492_5277.nii.gz 5277
# empty 191147
# /data/stroke/database/clinic/images/DL0492/5277_NCCT/191147_O.nii.gz
# created  191147
# DL0493_5278.nii.gz 5278
# empty 191148
# /data/stroke/database/clinic/images/DL0493/5278_NCCT/191148_O.nii.gz
# created  191148
# DL0521_5303.nii.gz 5303
# empty 191149
# /data/stroke/database/clinic/images/DL0521/5303_NCCT/191149_O.nii.gz
# created  191149
# DL0557_5339.nii.gz 5339
# empty 191150
# /data/stroke/database/clinic/images/DL0557/5339_NCCT/191150_O.nii.gz
# created  191150
# DL0572_5353.nii.gz 5353
# empty 191151
# /data/stroke/database/clinic/images/DL0572/5353_NCCT/191151_O.nii.gz
# created  191151
# DL0579_5359.nii.gz 5359
# empty 191152
# /data/stroke/database/clinic/images/DL0579/5359_NCCT/191152_O.nii.gz
# created  191152
# DL0591_5368.nii.gz 5368
# empty 191153
# /data/stroke/database/clinic/images/DL0591/5368_NCCT/191153_O.nii.gz
# created  191153
# DL0629_5402.nii.gz 5402
# empty 191154
# /data/stroke/database/clinic/images/DL0629/5402_NCCT/191154_O.nii.gz
# created  191154
# DL0636_5407.nii.gz 5407
# empty 191155
# /data/stroke/database/clinic/images/DL0636/5407_NCCT/191155_O.nii.gz
# created  191155
# DL0642_5411.nii.gz 5411
# empty 191156
# /data/stroke/database/clinic/images/DL0642/5411_NCCT/191156_O.nii.gz
# created  191156
# DL0668_5433.nii.gz 5433
# empty 191157
# /data/stroke/database/clinic/images/DL0668/5433_NCCT/191157_O.nii.gz
# created  191157
# DL0669_5434.nii.gz 5434
# empty 191158
# /data/stroke/database/clinic/images/DL0669/5434_NCCT/191158_O.nii.gz
# created  191158
# DL0677_5441.nii.gz 5441
# empty 191159
# /data/stroke/database/clinic/images/DL0677/5441_NCCT/191159_O.nii.gz
# created  191159
# DL0679_5443.nii.gz 5443
# empty 191160
# /data/stroke/database/clinic/images/DL0679/5443_NCCT/191160_O.nii.gz
# created  191160
# DL0684_5448.nii.gz 5448
# empty 191161
# /data/stroke/database/clinic/images/DL0684/5448_NCCT/191161_O.nii.gz
# created  191161
# DL0696_5458.nii.gz 5458
# empty 191162
# /data/stroke/database/clinic/images/DL0696/5458_NCCT/191162_O.nii.gz
# created  191162
# DL0708_5469.nii.gz 5469
# empty 191163
# /data/stroke/database/clinic/images/DL0708/5469_NCCT/191163_O.nii.gz
# created  191163
# DL0736_5491.nii.gz 5491
# empty 191164
# /data/stroke/database/clinic/images/DL0736/5491_NCCT/191164_O.nii.gz
# created  191164
# DL0740_5495.nii.gz 5495
# empty 191165
# /data/stroke/database/clinic/images/DL0740/5495_NCCT/191165_O.nii.gz
# created  191165
# DL0758_5511.nii.gz 5511
# empty 191166
# /data/stroke/database/clinic/images/DL0758/5511_NCCT/191166_O.nii.gz
# created  191166
# DL0759_5512.nii.gz 5512
# empty 191167
# /data/stroke/database/clinic/images/DL0759/5512_NCCT/191167_O.nii.gz
# created  191167
# DL0769_5520.nii.gz 5520
# empty 191168
# /data/stroke/database/clinic/images/DL0769/5520_NCCT/191168_O.nii.gz
# created  191168
# DL0784_5529.nii.gz 5529
# empty 191169
# /data/stroke/database/clinic/images/DL0784/5529_NCCT/191169_O.nii.gz
# created  191169
# DL0809_5548.nii.gz 5548
# empty 191170
# /data/stroke/database/clinic/images/DL0809/5548_NCCT/191170_O.nii.gz
# created  191170
# DL1001_25988.nii.gz 25988
# empty 191171
# /data/stroke/database/clinic/images/DL1001/25988_NCCT/191171_O.nii.gz
# created  191171
# DL1005_25996.nii.gz 25996
# empty 191172
# /data/stroke/database/clinic/images/DL1005/25996_NCCT/191172_O.nii.gz
# created  191172
# DL1007_26000.nii.gz 26000
# empty 191173
# /data/stroke/database/clinic/images/DL1007/26000_NCCT/191173_O.nii.gz
# created  191173
# DL1009_26004.nii.gz 26004
# empty 191174
# /data/stroke/database/clinic/images/DL1009/26004_NCCT/191174_O.nii.gz
# created  191174
# DL1023_26024.nii.gz 26024
# empty 191175
# /data/stroke/database/clinic/images/DL1023/26024_NCCT/191175_O.nii.gz
# created  191175
# DL1025_26028.nii.gz 26028
# empty 191176
# /data/stroke/database/clinic/images/DL1025/26028_NCCT/191176_O.nii.gz
# created  191176
# DL1032_26038.nii.gz 26038
# empty 191177
# /data/stroke/database/clinic/images/DL1032/26038_NCCT/191177_O.nii.gz
# created  191177
# DL1043_26058.nii.gz 26058
# empty 191178
# /data/stroke/database/clinic/images/DL1043/26058_NCCT/191178_O.nii.gz
# created  191178
# DL1048_26066.nii.gz 26066
# empty 191179
# /data/stroke/database/clinic/images/DL1048/26066_NCCT/191179_O.nii.gz
# created  191179
# DL1050_26068.nii.gz 26068
# empty 191180
# /data/stroke/database/clinic/images/DL1050/26068_NCCT/191180_O.nii.gz
# created  191180
# DL1076_26112.nii.gz 26112
# empty 191181
# /data/stroke/database/clinic/images/DL1076/26112_NCCT/191181_O.nii.gz
# created  191181
# DL1078_26116.nii.gz 26116
# empty 191182
# /data/stroke/database/clinic/images/DL1078/26116_NCCT/191182_O.nii.gz
# created  191182
# DL1081_26122.nii.gz 26122
# empty 191183
# /data/stroke/database/clinic/images/DL1081/26122_NCCT/191183_O.nii.gz
# created  191183
# DL1090_26140.nii.gz 26140
# empty 191184
# /data/stroke/database/clinic/images/DL1090/26140_NCCT/191184_O.nii.gz
# created  191184
# DL1094_26148.nii.gz 26148
# empty 191185
# /data/stroke/database/clinic/images/DL1094/26148_NCCT/191185_O.nii.gz
# created  191185
# DL1097_26154.nii.gz 26154
# empty 191186
# /data/stroke/database/clinic/images/DL1097/26154_NCCT/191186_O.nii.gz
# created  191186
# DL1105_26170.nii.gz 26170
# empty 191187
# /data/stroke/database/clinic/images/DL1105/26170_NCCT/191187_O.nii.gz
# created  191187
# DL1110_26180.nii.gz 26180
# empty 191188
# /data/stroke/database/clinic/images/DL1110/26180_NCCT/191188_O.nii.gz
# created  191188
# DL1112_26182.nii.gz 26182
# empty 191189
# /data/stroke/database/clinic/images/DL1112/26182_NCCT/191189_O.nii.gz
# created  191189
# DL1115_26186.nii.gz 26186
# empty 191190
# /data/stroke/database/clinic/images/DL1115/26186_NCCT/191190_O.nii.gz
# created  191190
# DL1117_26188.nii.gz 26188
# empty 191191
# /data/stroke/database/clinic/images/DL1117/26188_NCCT/191191_O.nii.gz
# created  191191
# DL1119_26190.nii.gz 26190
# empty 191192
# /data/stroke/database/clinic/images/DL1119/26190_NCCT/191192_O.nii.gz
# created  191192
# DL1121_26194.nii.gz 26194
# empty 191193
# /data/stroke/database/clinic/images/DL1121/26194_NCCT/191193_O.nii.gz
# created  191193
# DL1126_26202.nii.gz 26202
# empty 191194
# /data/stroke/database/clinic/images/DL1126/26202_NCCT/191194_O.nii.gz
# created  191194
# DL1130_26206.nii.gz 26206
# empty 191195
# /data/stroke/database/clinic/images/DL1130/26206_NCCT/191195_O.nii.gz
# created  191195
# DL1132_26208.nii.gz 26208
# empty 191196
# /data/stroke/database/clinic/images/DL1132/26208_NCCT/191196_O.nii.gz
# created  191196
# DL1135_26212.nii.gz 26212
# empty 191197
# /data/stroke/database/clinic/images/DL1135/26212_NCCT/191197_O.nii.gz
# created  191197
# DL1138_26216.nii.gz 26216
# empty 191198
# /data/stroke/database/clinic/images/DL1138/26216_NCCT/191198_O.nii.gz
# created  191198
# DL1160_26252.nii.gz 26252
# empty 191199
# /data/stroke/database/clinic/images/DL1160/26252_NCCT/191199_O.nii.gz
# created  191199
# DL1170_26270.nii.gz 26270
# empty 191200
# /data/stroke/database/clinic/images/DL1170/26270_NCCT/191200_O.nii.gz
# created  191200
# DL1185_26300.nii.gz 26300
# empty 191201
# /data/stroke/database/clinic/images/DL1185/26300_NCCT/191201_O.nii.gz
# created  191201
# DL1187_26304.nii.gz 26304
# empty 191202
# /data/stroke/database/clinic/images/DL1187/26304_NCCT/191202_O.nii.gz
# created  191202
# DL1189_26308.nii.gz 26308
# empty 191203
# /data/stroke/database/clinic/images/DL1189/26308_NCCT/191203_O.nii.gz
# created  191203
# DL1192_26314.nii.gz 26314
# empty 191204
# /data/stroke/database/clinic/images/DL1192/26314_NCCT/191204_O.nii.gz
# created  191204
# DL1193_26316.nii.gz 26316
# empty 191205
# /data/stroke/database/clinic/images/DL1193/26316_NCCT/191205_O.nii.gz
# created  191205
# DL1195_26320.nii.gz 26320
# empty 191206
# /data/stroke/database/clinic/images/DL1195/26320_NCCT/191206_O.nii.gz
# created  191206
# DL1205_26340.nii.gz 26340
# empty 191207
# /data/stroke/database/clinic/images/DL1205/26340_NCCT/191207_O.nii.gz
# created  191207
# DL1207_26344.nii.gz 26344
# empty 191208
# /data/stroke/database/clinic/images/DL1207/26344_NCCT/191208_O.nii.gz
# created  191208
# DL1209_26348.nii.gz 26348
# empty 191209
# /data/stroke/database/clinic/images/DL1209/26348_NCCT/191209_O.nii.gz
# created  191209
# DL1210_26350.nii.gz 26350
# empty 191210
# /data/stroke/database/clinic/images/DL1210/26350_NCCT/191210_O.nii.gz
# created  191210
# DL1213_26356.nii.gz 26356
# empty 191211
# /data/stroke/database/clinic/images/DL1213/26356_NCCT/191211_O.nii.gz
# created  191211
# DL1222_26368.nii.gz 26368
# empty 191212
# /data/stroke/database/clinic/images/DL1222/26368_NCCT/191212_O.nii.gz
# created  191212
# DL1226_26372.nii.gz 26372
# empty 191213
# /data/stroke/database/clinic/images/DL1226/26372_NCCT/191213_O.nii.gz
# created  191213
# DL1191_26312.nii.gz 26312
# empty 191214
# /data/stroke/database/clinic/images/DL1191/26312_NCCT/191214_O.nii.gz
# created  191214
# DL0805_5545.nii.gz 5545
# empty 191215
# /data/stroke/database/clinic/images/DL0805/5545_NCCT/191215_O.nii.gz
# created  191215
# DL0719_10107.nii.gz 10107
# empty 191216
# /data/stroke/database/clinic/images/DL0719/10107_NCCT/191216_O.nii.gz
# created  191216
# DL0667_10101.nii.gz 10101
# empty 191217
# /data/stroke/database/clinic/images/DL0667/10101_NCCT/191217_O.nii.gz
# created  191217
# DL0270_10069.nii.gz 10069
# empty 191218
# /data/stroke/database/clinic/images/DL0270/10069_NCCT/191218_O.nii.gz
# created  191218
# DL0812_5550.nii.gz 5550
# empty 191219
# /data/stroke/database/clinic/images/DL0812/5550_NCCT/191219_O.nii.gz
# created  191219
# DL0810_10124.nii.gz 10124
# empty 191220
# /data/stroke/database/clinic/images/DL0810/10124_NCCT/191220_O.nii.gz
# created  191220
# DL0741_5496.nii.gz 5496
# empty 191221
# /data/stroke/database/clinic/images/DL0741/5496_NCCT/191221_O.nii.gz
# created  191221
# DL0801_5541.nii.gz 5541
# empty 191222
# /data/stroke/database/clinic/images/DL0801/5541_NCCT/191222_O.nii.gz
# created  191222
# DL0415_5209.nii.gz 5209
# empty 191223
# /data/stroke/database/clinic/images/DL0415/5209_NCCT/191223_O.nii.gz
# created  191223
# DL1028_67738.nii.gz 67738
# empty 191224
# /data/stroke/database/clinic/images/DL1028/67738_NCCT/191224_O.nii.gz
# created  191224
# DL1142_67739.nii.gz 67739
# empty 191225
# /data/stroke/database/clinic/images/DL1142/67739_NCCT/191225_O.nii.gz
# created  191225
